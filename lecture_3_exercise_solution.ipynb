# %% [markdown]
# # Lecture 3 in-class exercise solution

# %% [markdown]
# Ensure the visualizations [render](https://plotly.com/python/renderers/) properly across VSCode, Jupyter Book, etc. You can ignore this.

# %%
import plotly.io as pio

pio.renderers.default = "colab+notebook_connected+plotly_mimetype"

# %%
import pandas as pd

# load all records and force a consistent ordering
parks = pd.read_csv(
    "https://data.cityofnewyork.us/resource/enfh-gkve.csv?$limit=3000&$order=globalid"
)
parks
# Out:
#               acquisitiondate    acres  \
# 0     1934-07-11T00:00:00.000    1.800
# 1     1926-04-21T00:00:00.000    0.271
# 2     1945-01-16T00:00:00.000    3.380
# 3     1947-03-13T00:00:00.000    0.208
# 4     1968-07-25T00:00:00.000    0.284
# ...                       ...      ...
# 2053  1933-05-24T00:00:00.000    0.525
# 2054  2002-11-20T00:00:00.000    0.172
# 2055  1962-09-07T00:00:00.000  104.600
# 2056  1947-05-25T00:00:00.000    0.964
# 2057  1991-09-03T00:00:00.000    1.430
#
#                                                 address borough class  \
# 0                W 179 St bet. Cedar Av and Sedgwick Av       X  PARK
# 1                          Harbor Rd. at Richmond Terr.       R  PARK
# 2                                  1405 ATLANTIC AVENUE       B  PARK
# 3                                   610 ROCKAWAY AVENUE       B  PARK
# 4               Greystone Av bet. W 236 St and W 240 St       X  PARK
# ...                                                 ...     ...   ...
# 2053                                 317 WEST 16 STREET       M  PARK
# 2054                                   79-85 Montauk St       B  PARK
# 2055                              6320 MARATHON PARKWAY       Q  PARK
# 2056            Nostrand Ave. between Ave. L and Ave. K       B  PARK
# 2057  N. Gannon Ave., Willow Road E., Victory Blvd.,...       R  PARK
#
#      communityboard councildistrict department   gisobjid gispropnum  ...  \
# 0               205              16       X-05  100005000       X111  ...
# 1               501              49       R-01  100003827       R036  ...
# 2               303              36       B-03  100004719       B225  ...
# 3               316              41       B-16  100003833       B227  ...
# 4               208              11       X-08  100004267       X224  ...
# ...             ...             ...        ...        ...        ...  ...
# 2053            104               3       M-04  100004586       M066  ...
# 2054            305              37       B-05  100003705       B491  ...
# 2055            411              23       Q-11  100000252       Q411  ...
# 2056            314              45       B-14  100004580       B287  ...
# 2057            501              50       R-01  100004383       R126  ...
#
#      pip_ratable precinct retired                          signname  \
# 0           True       46   False                  Cedar Playground
# 1           True      120   False       Bobbie Lewis Jr. Playground
# 2           True       79   False           St. Andrew's Playground
# 3           True       73   False               P.S. 125 Playground
# 4           True       50   False            MacLaughlin Playground
# ...          ...      ...     ...                               ...
# 2053        True       10   False  Dr. Gertrude B. Kelly Playground
# 2054       False       75   False                   Shield Of Faith
# 2055       False      111   False       Douglaston Park Golf Course
# 2056        True       70   False                Andries Playground
# 2057        True      120   False                        Gaeta Park
#
#                      subcategory                 typecategory  us_congress  \
# 0              Neighborhood Plgd            Neighborhood Park         13.0
# 1              Neighborhood Plgd            Neighborhood Park         11.0
# 2              Neighborhood Plgd            Neighborhood Park          8.0
# 3                            JOP                   Playground          8.0
# 4              Neighborhood Plgd                   Playground         15.0
# ...                          ...                          ...          ...
# 2053           Neighborhood Plgd            Neighborhood Park         12.0
# 2054                  Greenthumb                       Garden          7.0
# 2055                  Large Park                Managed Sites          3.0
# 2056                         JOP  Jointly Operated Playground          9.0
# 2057  Sitting Area/Triangle/Mall               Triangle/Plaza         11.0
#
#       waterfront zipcode                                       multipolygon
# 0          False   10453  MULTIPOLYGON (((-73.91697310271871 40.85481428...
# 1          False   10303  MULTIPOLYGON (((-74.16025193367476 40.63669457...
# 2          False   11216  MULTIPOLYGON (((-73.94148303666111 40.67816967...
# 3          False   11212  MULTIPOLYGON (((-73.90940657813228 40.66516627...
# 4          False   10471  MULTIPOLYGON (((-73.90512615406934 40.88815910...
# ...          ...     ...                                                ...
# 2053       False   10011  MULTIPOLYGON (((-74.00197756530805 40.74134480...
# 2054       False   11208  MULTIPOLYGON (((-73.87829126928358 40.67745132...
# 2055       False   11362  MULTIPOLYGON (((-73.73320415943988 40.75444962...
# 2056       False   11210  MULTIPOLYGON (((-73.94637406393018 40.62340014...
# 2057       False   10314  MULTIPOLYGON (((-74.15046757766655 40.61042193...
#
# [2058 rows x 33 columns]

# %%
import plotly.express as px

px.histogram(
    parks,
    x="borough",
    title="Number of parks per borough",
)
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="8307b0f0-dc03-43fb-aafa-1d8bae1730f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8307b0f0-dc03-43fb-aafa-1d8bae1730f7")) {                    Plotly.newPlot(                        "8307b0f0-dc03-43fb-aafa-1d8bae1730f7",                        [{"bingroup":"x","hovertemplate":"borough=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"x":["X","R","B","B","X","B","X","M","Q","M","B","R","Q","R","B","B","R","Q","M","M","B","M","Q","M","X","Q","X","X","M","B","Q","M","X","Q","X","Q","X","B","Q","B","X","B","M","B","B","R","Q","Q","Q","B","B","X","M","M","Q","X","M","Q","Q","Q","R","Q","Q","R","B","X","B","B","B","R","X","Q","B","Q","M","M","Q","M","X","X","M","Q","B","Q","Q","M","X","R","M","R","B","M","R","Q","X","Q","M","B","M","Q","M","X","B","M","Q","Q","M","B","M","Q","Q","B","X","Q","Q","M","Q","B","B","X","B","X","X","Q","Q","M","B","M","M","B","M","X","X","Q","Q","B","M","M","R","B","B","B","B","X","M","M","X","Q","M","B","X","M","B","B","M","B","B","X","B","X","M","B","X","Q","M","M","X","M","Q","B","M","M","R","X","Q","X","M","B","X","B","Q","